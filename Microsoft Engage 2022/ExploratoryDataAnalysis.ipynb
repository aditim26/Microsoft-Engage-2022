# %%
pwd
# Out:
# 'C:\\Users\\dell\\Microsoft'

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel('C:\\Users\\dell\\Desktop\\microsoft\\DataSet.xlsx')

# %%
df.head()
# Out:
#             Make        Model      Variant  Showroom_Price  \
# 0           Tata    Nano Genx           Xe          236447
# 1          Bajaj  Qute (Re60)         Qcar          263000
# 2           Tata    Nano Genx           Xm          272223
# 3         Datsun      Redi-Go            D          279650
# 4  Maruti Suzuki         Omni  5 Str Bs-Iv          282778
#
#    Displacement in cc  Cylinders  Valves_Per_Cylinder  \
# 0               624.0        2.0                  2.0
# 1               216.0        NaN                  1.0
# 2               624.0        2.0                  2.0
# 3               799.0        3.0                  4.0
# 4               796.0        3.0                  2.0
#
#                 Drivetrain Cylinder_Configuration Emission_Norm  ...  \
# 0   RWD (Rear Wheel Drive)                In-line         BS IV  ...
# 1   RWD (Rear Wheel Drive)                In-line         BS IV  ...
# 2   RWD (Rear Wheel Drive)                In-line         BS IV  ...
# ...

# %%
df.shape
# Out:
# (1276, 131)

# %%
df['Make'].value_counts()
# Out:
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Mercedes-Benz        57
# Skoda                43
# Ford                 43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Datsun               24
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Maruti Suzuki R      14
# Porsche              14
# Lamborghini          13
# Mg                   13
# Icml                 11
# Mini                 10
# Lexus                10
# Land Rover           10
# Maserati              9
# Rolls-Royce           9
# Ferrari               8
# Mitsubishi            7
# Premier               6
# Force                 6
# Bentley               6
# Isuzu                 5
# Aston Martin          3
# ...

# %%
sns.kdeplot(data=df['Showroom_Price'],label="Showroom_Price",shade=True)
# Out:
# <AxesSubplot:xlabel='Showroom_Price', ylabel='Density'>

# %%
df['Showroom_Price'].describe()
# Out:
# count    1.276000e+03
# mean     4.596538e+06
# std      1.214735e+07
# min      2.364470e+05
# 25%      7.438760e+05
# 50%      1.060064e+06
# 75%      2.979828e+06
# max      2.121554e+08
# Name: Showroom_Price, dtype: float64

# %%
df['Showroom_Price'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Showroom_Price']=df['Showroom_Price'].round(5)
df['Showroom_Price']
# Out:
# 0          236447
# 1          263000
# 2          272223
# 3          279650
# 4          282778
#           ...
# 1271     77312661
# 1272     83755383
# 1273     95000000
# 1274    192142937
# 1275    212155397
# Name: Showroom_Price, Length: 1276, dtype: int64

# %%
df.nunique()
# Out:
# Make                                  41
# Model                                263
# Variant                             1064
# Showroom_Price                      1179
# Displacement in cc                   129
#                                     ...
# Cruise_Control                         1
# Heads-Up_Display                       1
# Welcome_Lights                         1
# Battery                                5
# Electric_Range in km/full charge       8
# Length: 131, dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                                   0
# Model                                  0
# Variant                                0
# Showroom_Price                         0
# Displacement in cc                    12
#                                     ...
# Cruise_Control                       727
# Heads-Up_Display                    1225
# Welcome_Lights                      1207
# Battery                             1263
# Electric_Range in km/full charge    1259
# Length: 131, dtype: int64

# %%
data=df.set_index('Make')
data.head()
# Out:
#                      Model      Variant  Showroom_Price  Displacement in cc  \
# Make
# Tata             Nano Genx           Xe          236447               624.0
# Bajaj          Qute (Re60)         Qcar          263000               216.0
# Tata             Nano Genx           Xm          272223               624.0
# Datsun             Redi-Go            D          279650               799.0
# Maruti Suzuki         Omni  5 Str Bs-Iv          282778               796.0
#
#                Cylinders  Valves_Per_Cylinder               Drivetrain  \
# Make
# Tata                 2.0                  2.0   RWD (Rear Wheel Drive)
# Bajaj                NaN                  1.0   RWD (Rear Wheel Drive)
# Tata                 2.0                  2.0   RWD (Rear Wheel Drive)
# Datsun               3.0                  4.0  FWD (Front Wheel Drive)
# Maruti Suzuki        3.0                  2.0   RWD (Rear Wheel Drive)
#
# ...

# %%
data.sort_index(axis=0, ascending=True)
# Out:
#                           Model               Variant  Showroom_Price  \
# Make
# Aston Martin              Db 11                   V12        40456503
# Aston Martin             Rapide                  Luxe        38845823
# Aston Martin            Vantage                 Coupe        29500000
# Audi                         Q5  45 Tfsi Premium Plus         5021200
# Audi                         A3    35 Tfsi Technology         3120750
# ...                         ...                   ...             ...
# Volvo                       V40               Kinetic         2769000
# Volvo                      Xc90        D5 Inscription         8790000
# Volvo                       S90        D4 Inscription         5890000
# Volvo                      Xc90         T8 Excellence        13124000
# Volvo         S60 Cross Country                    D4         4426500
#
#               Displacement in cc  Cylinders  Valves_Per_Cylinder  \
# Make
# ...
